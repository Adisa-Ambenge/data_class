# %%
import nltk
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
nltk.download("twitter_samples")
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/user/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %%
from nltk.corpus import twitter_samples

# %%
len(twitter_samples.fileids())
# Out:
# 3

# %%
negative_fileids = twitter_samples.fileids()
positive_fileids = twitter_samples.fileids()

# %%
len(negative_fileids),len(positive_fileids)
# Out:
# (3, 3)

# %%
print(twitter_samples.raw(fileids=positive_fileids[0])[:1000])
# Out:
# {"contributors": null, "coordinates": null, "text": "hopeless for tmr :(", "user": {"screen_name": "yuwraxkim", "time_zone": "Jakarta", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/585476378365014016/j1mvQu3c.png", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/585476378365014016/j1mvQu3c.png", "default_profile_image": false, "url": null, "profile_text_color": "000000", "following": false, "listed_count": 3, "entities": {"description": {"urls": []}}, "utc_offset": 25200, "profile_sidebar_border_color": "000000", "name": "yuwra \u2708 ", "favourites_count": 196, "followers_count": 1281, "location": "wearegsd;favor;pucukfams;barbx", "protected": false, "notifications": false, "profile_image_url_https": "https://pbs.twimg.com/profile_images/622631732399898624/kmYsX_k1_normal.jpg", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/622631732399898624/kmYsX_k1_normal.jpg
# ...

# %%
twitter_text = """{"contributors": null, "coordinates": null, "text": "hopeless for tmr :(", "user": {"screen_name": "yuwraxkim", "time_zone": "Jakarta", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/585476378365014016/j1mvQu3c.png", "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/585476378365014016/j1mvQu3c.png", "default_profile_image": false, "url": null, "profile_text_color": "000000", "following": false, "listed_count": 3, "entities": {"description": {"urls": []}}, "utc_offset": 25200, "profile_sidebar_border_color": "000000", "name": "yuwra \u2708 ", "favourites_count": 196, "followers_count": 1281, "location": "wearegsd;favor;pucukfams;barbx", "protected": false, "notifications": false, "profile_image_url_https": "https://pbs.twimg.com/profile_images/622631732399898624/kmYsX_k1_normal.jpg", "profile_use_background_image": true, "profile_image_url": "http://pbs.twimg.com/profile_images/622631732399898624/kmYsX_k1_normal.jpg","""

# %%
twitter_text.split()
# Out:
# ['{"contributors":',
#  'null,',
#  '"coordinates":',
#  'null,',
#  '"text":',
#  '"hopeless',
#  'for',
#  'tmr',
#  ':(",',
#  '"user":',
#  '{"screen_name":',
#  '"yuwraxkim",',
#  '"time_zone":',
#  '"Jakarta",',
#  '"profile_background_image_url":',
#  '"http://pbs.twimg.com/profile_background_images/585476378365014016/j1mvQu3c.png",',
#  '"profile_background_image_url_https":',
#  '"https://pbs.twimg.com/profile_background_images/585476378365014016/j1mvQu3c.png",',
#  '"default_profile_image":',
#  'false,',
#  '"url":',
#  'null,',
#  '"profile_text_color":',
#  '"000000",',
#  '"following":',
#  'false,',
#  '"listed_count":',
#  '3,',
#  '"entities":',
#  '{"description":',
#  '{"urls":',
#  '[]}},',
#  '"utc_offset":',
#  '25200,',
#  '"profile_sidebar_border_color":',
#  '"000000",',
#  '"name":',
#  '"yuwra',
#  '✈',
#  '",',
#  '"favourites_count":',
#  '196,',
#  '"followers_count":',
#  '1281,',
#  '"location":',
#  '"wearegsd;favor;pucukfams;barbx",',
# ...

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /home/user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
twitter_texts = nltk.word_tokenize(twitter_text)

# %%
twitter_texts
# Out:
# ['{',
#  '``',
#  'contributors',
#  "''",
#  ':',
#  'null',
#  ',',
#  '``',
#  'coordinates',
#  "''",
#  ':',
#  'null',
#  ',',
#  '``',
#  'text',
#  "''",
#  ':',
#  '``',
#  'hopeless',
#  'for',
#  'tmr',
#  ':',
#  '(',
#  '``',
#  ',',
#  '``',
#  'user',
#  "''",
#  ':',
#  '{',
#  '``',
#  'screen_name',
#  "''",
#  ':',
#  '``',
#  'yuwraxkim',
#  "''",
#  ',',
#  '``',
#  'time_zone',
#  "''",
#  ':',
#  '``',
#  'Jakarta',
#  "''",
#  ',',
#  '``',
#  'profile_background_image_url',
#  "''",
#  ':',
#  '``',
#  'http',
#  ':',
#  '//pbs.twimg.com/profile_background_images/585476378365014016/j1mvQu3c.png',
#  "''",
#  ',',
#  '``',
#  'profile_background_image_url_https',
#  "''",
#  ':',
#  '``',
#  'https',
#  ':',
#  '//pbs.twimg.com/profile_background_images/585476378365014016/j1mvQu3c.png',
#  "''",
#  ',',
#  '``',
#  'default_profile_image',
#  "''",
#  ':',
#  'false',
#  ',',
#  '``',
#  'url',
#  "''",
#  ':',
#  'null',
#  ',',
#  '``',
# ...

# %%
{word: True for word in twitter_texts}
# Out:
# {'{': True,
#  '``': True,
#  'contributors': True,
#  "''": True,
#  ':': True,
#  'null': True,
#  ',': True,
#  'coordinates': True,
#  'text': True,
#  'hopeless': True,
#  'for': True,
#  'tmr': True,
#  '(': True,
#  'user': True,
#  'screen_name': True,
#  'yuwraxkim': True,
#  'time_zone': True,
#  'Jakarta': True,
#  'profile_background_image_url': True,
#  'http': True,
#  '//pbs.twimg.com/profile_background_images/585476378365014016/j1mvQu3c.png': True,
#  'profile_background_image_url_https': True,
#  'https': True,
#  'default_profile_image': True,
#  'false': True,
#  'url': True,
#  'profile_text_color': True,
#  '000000': True,
#  'following': True,
#  'listed_count': True,
#  '3': True,
#  'entities': True,
#  'description': True,
#  'urls': True,
#  '[': True,
#  ']': True,
#  '}': True,
#  'utc_offset': True,
#  '25200': True,
#  'profile_sidebar_border_color': True,
#  'name': True,
#  'yuwra': True,
#  '✈': True,
#  'favourites_count': True,
#  '196': True,
# ...

# %%
def build_bag_of_words_features(words):
    return {word: True for word in words}

# %%
build_bag_of_words_features(twitter_texts)
# Out:
# {'{': True,
#  '``': True,
#  'contributors': True,
#  "''": True,
#  ':': True,
#  'null': True,
#  ',': True,
#  'coordinates': True,
#  'text': True,
#  'hopeless': True,
#  'for': True,
#  'tmr': True,
#  '(': True,
#  'user': True,
#  'screen_name': True,
#  'yuwraxkim': True,
#  'time_zone': True,
#  'Jakarta': True,
#  'profile_background_image_url': True,
#  'http': True,
#  '//pbs.twimg.com/profile_background_images/585476378365014016/j1mvQu3c.png': True,
#  'profile_background_image_url_https': True,
#  'https': True,
#  'default_profile_image': True,
#  'false': True,
#  'url': True,
#  'profile_text_color': True,
#  '000000': True,
#  'following': True,
#  'listed_count': True,
#  '3': True,
#  'entities': True,
#  'description': True,
#  'urls': True,
#  '[': True,
#  ']': True,
#  '}': True,
#  'utc_offset': True,
#  '25200': True,
#  'profile_sidebar_border_color': True,
#  'name': True,
#  'yuwra': True,
#  '✈': True,
#  'favourites_count': True,
#  '196': True,
# ...

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /home/user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
useless_words = nltk.corpus.stopwords.words("english")
list(string.punctuation)
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
useless_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
def build_bag_of_words_features_filtered(words):
    return{
        word:1 for word in words \
    if not word in useless_words}

# %%
build_bag_of_words_features_filtered(twitter_texts)
# Out:
# {'{': 1,
#  '``': 1,
#  'contributors': 1,
#  "''": 1,
#  ':': 1,
#  'null': 1,
#  ',': 1,
#  'coordinates': 1,
#  'text': 1,
#  'hopeless': 1,
#  'tmr': 1,
#  '(': 1,
#  'user': 1,
#  'screen_name': 1,
#  'yuwraxkim': 1,
#  'time_zone': 1,
#  'Jakarta': 1,
#  'profile_background_image_url': 1,
#  'http': 1,
#  '//pbs.twimg.com/profile_background_images/585476378365014016/j1mvQu3c.png': 1,
#  'profile_background_image_url_https': 1,
#  'https': 1,
#  'default_profile_image': 1,
#  'false': 1,
#  'url': 1,
#  'profile_text_color': 1,
#  '000000': 1,
#  'following': 1,
#  'listed_count': 1,
#  '3': 1,
#  'entities': 1,
#  'description': 1,
#  'urls': 1,
#  '[': 1,
#  ']': 1,
#  '}': 1,
#  'utc_offset': 1,
#  '25200': 1,
#  'profile_sidebar_border_color': 1,
#  'name': 1,
#  'yuwra': 1,
#  '✈': 1,
#  'favourites_count': 1,
#  '196': 1,
#  'followers_count': 1,
#  '1281': 1,
#  'location': 1,
#  'wearegsd': 1,
#  ';': 1,
#  'favor': 1,
#  'pucukfams': 1,
#  'barbx': 1,
# ...

# %%
wordcloud = WordCloud(width = 800,height = 400,background_color = "white").generate(twitter_text)
plt.figure(figsize = (10,5))
plt.imshow(wordcloud,interpolation = 'bilinear')
plt.axis('off')
plt.show()
